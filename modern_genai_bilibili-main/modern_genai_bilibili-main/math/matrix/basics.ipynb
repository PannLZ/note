# %% [markdown]
# - cross product：两个向量的叉积，垂直于这两个向量所在的平面。这就是平面的法向量。
# - 点 $P(x_0, y_0, z_0)$ 到平面 $ax+by+cz+d=0$ 的距离 $D$通常是 $D = \frac{|ax_0 + by_0 + cz_0 + d|}{\sqrt{a^2 + b^2 + c^2}}$。
#     - 对于平面方程 $ax+by+cz+d=0$，其法向量（Normal Vector）是：$\vec{n} = (a, b, c)$
#     - 法向量 $\vec{n}$ 垂直于平面上的任意一条直线。
