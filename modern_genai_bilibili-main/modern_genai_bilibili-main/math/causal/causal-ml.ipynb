# %% [markdown]
# - https://www.nature.com/articles/s41591-024-02902-1：Causal machine learning for predicting treatment outcomes
#     - Predict treatment outcome
#     - traditional ML：相关性分析，association analysis
