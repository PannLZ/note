# %% [markdown]
# - 残差连接的公式 $x_{\ell+1} = x_\ell + \mathcal{F}(x_\ell)$ 在数学形式上完全等同于欧拉离散化（Euler discretization）。
# - 如果我们把层数 $\ell$ 看作时间 $t$，这个公式其实是微分方程的离散形式：$$\frac{x_{\ell+1} - x_\ell}{1} = \mathcal{F}(x_\ell) \quad \longrightarrow \quad \frac{dx}{dt} = \mathcal{F}(x, t)$$
