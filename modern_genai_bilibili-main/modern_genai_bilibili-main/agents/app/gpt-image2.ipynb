# %% [markdown]
# - chat 深度讨论，搜索，准备足够信息量之后的 infographic（信息图）的输出
#     - https://chatgpt.com/c/69e82eeb-9198-83a7-a8de-957147375fb7
#     - 基于以上的讨论，生成一副全面而不丢失细节的 infographic
#         - visual notes
#     - human in the loop of agentic search, prepare the rich context

# %% [markdown]
# ### agentic search/coding -> context

# %% [markdown]
# > thinking (agentic searching/coding) -> preparing the generation prompts -> generating
#
# - very very raw prompts
# - https://chatgpt.com/c/69e9f68d-0a2c-83a9-a08b-0cd6b9a59ea2
#     - multiple design sampling
#     - 为这篇工作（Stabilizing Reinforcement Learning with LLMs: Formulation and Practices）生成一个学术顶会用的 poster，生成8版供我筛选
# - https://chatgpt.com/c/69e979cf-a3fc-83a7-9231-eb4fb44c5f35
#     - references
#         - https://research.perplexity.ai/articles/advancing-search-augmented-language-models
#             - 高质量的信源
#         - https://zhuanlan.zhihu.com/p/1975730596534830124
#     - 画幅：1/3 -> 3/1；
#     - 多图（consistency generation），img2pdf
#     - chat/context editing

# %% [markdown]
# ### Natural/Photorealism (Gabriel Goh)

# %% [markdown]
# > 有图也无真相；
# - check contents/details/logic
# - 信源出处 / 交叉检验
# - 就像如何check一段文本的真实性一样
