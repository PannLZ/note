# %% [markdown]
# > 通过反思、反馈、协作和自我重构等机制，LLM智能体正逐步摆脱固定行为模式，朝着更灵活智能的代理方向演进。
# - a Self-Improving Coding Agent
#     - https://github.com/MaximeRobeyns/self_improving_coding_agent
# - benchmark
#     - swebench

# %% [markdown]
# - prompt optimization
#     - https://arxiv.org/pdf/2305.03495
#         - gradient descent on text 其实就是 reflection
#     - https://blog.langchain.com/exploring-prompt-optimization/
