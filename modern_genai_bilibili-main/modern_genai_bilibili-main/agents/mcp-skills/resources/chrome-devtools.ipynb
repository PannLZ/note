# %% [markdown]
# - https://github.com/ChromeDevTools/chrome-devtools-mcp
#     - 会本地存储该浏览器的用户数据（比如各个平台的登录缓存等信息）
#         - `~/.cache/chrome-devtools-mcp/chrome-profile`

# %% [markdown]
# - application
#     - 前端调试：https://www.bilibili.com/video/BV1KM4y1G7EF/
