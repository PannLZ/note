# %% [markdown]
# ```shell
# npx skills-installer install @anthropics/claude-code/frontend-design --client codex
# ```
# - https://skillsmp.com/zh
# - https://github.com/ComposioHQ/awesome-claude-skills
# - https://mp.weixin.qq.com/s/hKAlv_RZUzbIv5pGpnoZqg
#     - anthropics/claude-code/frontend-design
#     - 在原版frontend-design skill的基础上，把你自己的品味（主色/字体/圆角/阴影/按钮风格）等等写进去，成为一个 新的skill，让模型每次都按你的品牌调性出图，表现更好
# - Scientific Skills
#     - https://github.com/K-Dense-AI/claude-scientific-skills

# %% [markdown]
# ### claude code

# %% [markdown]
# - `/plugin`
#     - 查找、安装与管理
# - https://github.com/anthropics/skills
#     - /plugin install document-skills@anthropic-agent-skills

# %% [markdown]
# ### 视觉类

# %% [markdown]
# - https://github.com/lxfater/nano-image-generator-skill.git
# - 绘图
#     - https://github.com/softaworks/agent-toolkit/tree/main
#         - drawio
#         - 系统层面安装 `brew install --cask drawio`
#         - `画一个电商微服务架构图，包含api网关，用户服务，订单服务，支付服务和 kafka 消息队列`

# %% [markdown]
# ### canvas-design

# %% [markdown]
# - canvas-design: Skill = 专业的指令 (Prompt) + 必要的工具 (Resources)。
#     - "Prompt-as-Code" 和 "Resource-Augmented Generation"
#     - The Two-Step Workflow)：Prompt 强制 Claude 分两步执行任务：
#         - Design Philosophy Creation (.md)：先定义“设计哲学”。
#         - Visual Expression (.pdf/.png)：再基于哲学进行“视觉表达”。
#     - 资源的 link
#         - `IMPORTANT: Use different fonts if writing text. Search the ./canvas-fonts directory. Regardless of approach, sophistication is non-negotiable.`（重要提示：若需书写文本，请使用不同的字体。请在 ./canvas-fonts 目录下查找。无论采用何种方式，都必须确保（成品的）精致感/高级感，这是硬性要求（绝不容妥协）。）
