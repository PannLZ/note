# %%
from IPython.display import Image

# %% [markdown]
# - 负向 prompts
#     - 约束模型的行为，防止模型添油加醋，输出预期之外的内容；

# %% [markdown]
# ### workflow & prompts

# %%
Image(url='./figs/context-workflow.jpg', width=300)
# Out:
# <img src="./figs/context-workflow.jpg" width="300"/>
