# %% [markdown]
# ```markdown
# ## markdown syntax
# - never use em-dashes in your reply.
# - never use --- syntax in your reply.
# - only use heading 1 to 3 in your reply. heading 1 can only by used once, for title only. heading 4 should never be used, use bold instead.
# ```
