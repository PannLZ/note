# %%
from IPython.display import Image

# %% [markdown]
# ### CUA (Computer-Use Agent)

# %%
# https://developers.openai.com/api/docs/guides/tools-computer-use/
Image(url='https://cdn.openai.com/API/docs/images/cua_diagram.png', width=400)
# Out:
# <img src="https://cdn.openai.com/API/docs/images/cua_diagram.png" width="400"/>
