# %%
from IPython.display import Image

# %% [markdown]
# ### (3d) spatial understanding

# %% [markdown]
# - https://colab.research.google.com/github/google-gemini/cookbook/blob/main/examples/Spatial_understanding_3d.ipynb#scrollTo=WbWHzjtT6ELv
# - vlm：Visual spatial grounding，坐标生成能力，广泛的应用场景

# %%
Image(url='https://cdn.analyticsvidhya.com/wp-content/uploads/2025/11/image2-8.webp', width=150)
# Out:
# <img src="https://cdn.analyticsvidhya.com/wp-content/uploads/2025/11/image2-8.webp" width="150"/>
