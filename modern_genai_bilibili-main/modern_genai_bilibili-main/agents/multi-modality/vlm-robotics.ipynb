# %% [markdown]
# - Gemini Robotics-ER
#     - https://storage.googleapis.com/deepmind-media/gemini-robotics/Gemini-Robotics-1-5-Tech-Report.pdf
#     - https://ai.google.dev/gemini-api/docs/robotics-overview?hl=zh-cn
#     - https://github.com/google-gemini/cookbook/blob/main/quickstarts/gemini-robotics-er.ipynb
# - 数字世界、物理世界的鸿沟
#     - 自己的 location，world location；
