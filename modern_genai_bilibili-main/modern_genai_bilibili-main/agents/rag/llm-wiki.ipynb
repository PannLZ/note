# %% [markdown]
# - https://gist.github.com/karpathy/442a6bf555914893e9891c11519de94f
#     - LM incrementally builds and maintains a persistent wiki

# %% [markdown]
# ### qmd

# %% [markdown]
# > QMD - Query Markup Documents
