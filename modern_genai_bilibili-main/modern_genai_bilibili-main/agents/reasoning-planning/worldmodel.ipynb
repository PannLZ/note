# %% [markdown]
# - https://mp.weixin.qq.com/s/N5t-eSnzv2DpeA1K4OQh7A
#     - 预测“说什么” vs. 预测“会发生什么”
#     - llm 缺乏“惊讶”与学习机制：一个拥有世界模型的智能体，当现实世界的反馈与它的预测不符时，它会感到“惊讶”，并根据这种预期之外的事件来调整自己的模型。

# %%
from IPython.display import Image

# %%
Image(url='./figs/agentic_worldmodel.png', width=500)
# Out:
# <img src="./figs/agentic_worldmodel.png" width="500"/>

# %% [markdown]
# - When humans plan, we **imagine** the possible outcomes of different actions. When we reason about code we simulate part of its execution in our head.
