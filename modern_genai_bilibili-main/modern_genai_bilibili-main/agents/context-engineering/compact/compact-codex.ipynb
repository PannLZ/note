# %%
from IPython.display import Image

# %% [markdown]
# - https://x.com/kangwook_lee/status/2028955292025962534?s=46

# %% [markdown]
# ### 基本原理

# %% [markdown]
# - 先压缩后交接
#     - compact: https://github.com/openai/codex/blob/main/codex-rs/core/templates/compact/prompt.md
#     - handoff:  https://github.com/openai/codex/blob/main/codex-rs/core/templates/compact/summary_prefix.md
# - OpenAI provider 下走的是专门的远端 compact 路径，本地 provider/非 OpenAI 才走普通 responses 流式总结。（`provider.is_openai()`）
#     - compact_remote.rs
#         - POST /v1/responses/compact
#     - compact.rs
#         - POST /v1/responses
#         - 本地 compact 是“先压缩，再交接”：模型先输出总结，随后客户端本地拼 summary_text = SUMMARY_PREFIX + "\n" + last_assistant_message。

# %% [markdown]
# ```
# {
#     "model": "<model_info.slug>",
#     "instructions": "<sess.get_base_instructions().text>",
#     "input": [
#       ...已有历史...,
#       {
#         "type": "message",
#         "role": "user",
#         "content": [{ "type": "input_text", "text": "<turn_context.compact_prompt()>" }]
#       }
#     ],
#     "stream": true,
#     ...
#   }
# ```
# - templates/compact/prompt.md

# %%
# https://developers.openai.com/api/reference/python/resources/responses/methods/compact
Image(url='./figs/compact.jpeg', width=500)
# Out:
# <img src="./figs/compact.jpeg" width="500"/>
