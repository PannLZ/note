# %% [markdown]
# - 1106
#     - https://x.com/googleaistudio/status/1986127034800914543
#     - https://blog.google/technology/developers/gemini-api-structured-outputs/
