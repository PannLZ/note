# %% [markdown]
# - https://developers.googleblog.com/en/conversational-image-segmentation-gemini-2-5/
#     - https://aistudio.google.com/app/apps/bundled/spatial-understanding?showPreview=true&appParams=task%3Dsegmentation-masks&showAssistant=true
#     - https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Spatial_understanding.ipynb#scrollTo=WQJTJ8wdGOKx
#     - https://colab.research.google.com/drive/1eDvf_Ky9jLOZFShgHrm4GI-wkAaQnue6?usp=sharing#scrollTo=wizbxA1lm-Tj
# - news
#     - https://developers.googleblog.com/en/7-examples-of-geminis-multimodal-capabilities-in-action/
# - 后处理
#     - box_2d：返回值 x, y 要除以 1000 再乘以原始图像的宽度/高度
#         - `y1, x1, y2, x2 = box_2d`
#         - `x = int(x1 / 1000 * raw_width)`
#         - `y = int(y1 / 1000 * raw_height)`
#         - `w = int((x2 - x1) / 1000 * raw_width)`
#         - `h = int((y2 - y1) / 1000 * raw_height)`

# %% [markdown]
# ### segmentation

# %% [markdown]
# - https://ai.google.dev/gemini-api/docs/gemini-3?thinking=high&hl=zh-cn#migrating_from_gemini_25
#     - Gemini 3 Pro 不支持图片分割功能（返回对象的像素级遮罩）。对于需要原生图像分割的工作负载，我们建议继续使用关闭了思考功能的 Gemini 2.5 Flash 或 Gemini Robotics-ER 1.5。
#     - https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Spatial_understanding.ipynb#scrollTo=8t-MOFZcGjl_
#     - demos
#         - https://github.com/NSTiwari/Segmentation-using-Gemini
#         - https://github.com/pyresearch/Zero-Shot-Object-Detection-and-Segmentation-with-Google-Gemini-2.5

# %% [markdown]
# ```
# Give the segmentation masks for the objects.
# Output a JSON list of segmentation masks where each entry contains the 2D bounding box in "box_2d" and the mask in "mask".
# ```
# ```
# # 官方
# Give the segmentation masks for the objects.
# Output a JSON list of segmentation masks where each entry contains the 2D bounding box in the key "box_2d", the segmentation mask in key "mask", and the text label in the key "label".
# Use descriptive labels.
# ```

# %% [markdown]
# ### Beyond segmentation
