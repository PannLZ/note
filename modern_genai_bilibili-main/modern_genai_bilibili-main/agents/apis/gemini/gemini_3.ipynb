# %% [markdown]
# - https://ai.google.dev/gemini-api/docs/gemini-3
#     - thinking_level: low, medium, high
#     - media_resolution
#         - media_resolution_low、media_resolution_medium 或 media_resolution_high
#     - 对于 Gemini 3，我们强烈建议将温度参数保留为默认值 1.0。
# - https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Get_started.ipynb

# %% [markdown]
# ### 多模态

# %% [markdown]
# - With Gemini 3 Pro, image tokenization uses a **variable sequence length** which replaces the Pan and Scan method used in previous models for better quality and latency.
#     - 70 的倍数：70,280(\*4),560(\*8),1120(\*16);
#     - gemini 3.0 之前的 gemini models 对 image 进行 visual embedding 的方式是：pan(平移)-and-scan

# %% [markdown]
# ### thought-signatures (turn/steps)

# %% [markdown]
# https://ai.google.dev/gemini-api/docs/thought-signatures
# - 回合”是指用户与模型之间的一轮完整对话。“步骤”是指模型执行的更精细的操作，通常是完成一轮对话的较大流程的一部分。
