# %% [markdown]
# - some vqa of vlm
#     - recognize the objects in the bounding boxes. explain why for the rightmost box?

# %% [markdown]
# ### 图文理解

# %% [markdown]
# ```json
# {
#     "role": "system",
#     "content": "You are a helpful assistant that can analyze both text and image content to provide comprehensive answers.",
# },
# ```
# - user message: list of json
#     - 多图文交错
# ```json
# {'type': 'text', 'text': xx}
# {'type': 'image_url', 'image_url': {'url': 'data:image/jpeg....'}}
# {'type': 'text', 'text': xx}
# {'type': 'image_url', 'image_url': {'url': 'data:image/jpeg....'}}
# {'type': 'text', 'text': xx}
# {'type': 'image_url', 'image_url': {'url': 'data:image/jpeg....'}}
# ```
