# %% [markdown]
# - gemini：原点在左上角
#     - https://ai.google.dev/gemini-api/docs/image-understanding?hl=zh-cn
#         - 格式为 [y0, x0, y1, x1]，其中包含介于 0 到 1000 之间的归一化坐标；
#     - point：yx
#     - bbox：[y_min, x_min, y_max, x_max]（先 y 后 x）
# - qwen-vl
#     - https://www.alibabacloud.com/help/en/model-studio/vision
#     - point：xy
#     - bbox：xyxy
