# %% [markdown]
# - before model / after model / modify model request
#     - 埋点、钩子（hook） => 提升流程的可控性
# - 内置中间件
#     - https://docs.langchain.com/oss/python/langchain/middleware/built-in
#     - 集中体现了所谓的 context engineering
# - llm tool selector、to-do list、
#     - to-do list：会触发 write_tool 的调用
# - 自定义中间件
#     - FilesystemMiddleware：https://github.com/langchain-ai/deepagents-quickstarts
#         - 中间件会配备对应的 tools
