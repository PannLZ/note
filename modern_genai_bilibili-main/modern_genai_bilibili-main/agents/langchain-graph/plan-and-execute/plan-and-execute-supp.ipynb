# %%
from IPython.display import Image

# %% [markdown]
# - plan and execute: generate plan and execute each step
# - plan and execute ai agent
#     - understand user goal
#     - break down goal into steps
#     - execute each step
# - **dynamic adaptability**
#     - handle unexpected situations
#     - revise plan
#     - make adjustments to reach goal
# - use cases
#     - customer support automation
#     - job candidate screening
#     - event scheduling
#     - personalized recommendations

# %% [markdown]
# ### live music recommender based on real-time info

# %%
Image(url='./imgs/plan-and-execute.png', width=200)
# Out:
# <img src="./imgs/plan-and-execute.png" width="200"/>

# %% [markdown]
# - https://deepcharts.substack.com/p/build-a-plan-and-execute-ai-agent
#     - 重要的是，`event_lookup` 这个节点的条件转移输出：这里也能看到 langgraph workflow 定义的灵活性；
#         - to recommend_music_event: 形成一个循环（cycle）
#         - to executor：final output

# %% [markdown]
# - example case
#     - Prompt: `I'm looking for jazz music`
#     - Output: `Here are 3 live jazz music events tonight`
