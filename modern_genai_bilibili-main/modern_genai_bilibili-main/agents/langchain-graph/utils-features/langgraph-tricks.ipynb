# %% [markdown]
# ```python
# app = graph.compile(name='planner')
# ```
# - 给这个 graph 执行流程起一个有意义的别名，方便在 langsmith 中查看和定位，否则就是默认的 `LangGraph`
# - 如果是 llm chain，通过 `with_config({"run_name": "xx"})` 的方式 name
#
# ```python
# summary_chain = (prompt_template | llm | StrOutputParser()).with_config({"run_name": "plan-summary"})
# ```
