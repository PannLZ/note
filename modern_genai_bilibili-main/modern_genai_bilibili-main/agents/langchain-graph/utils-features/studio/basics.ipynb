# %% [markdown]
# - git@github.com:google-gemini/gemini-fullstack-langgraph-quickstart.git
#     - 这个项目的 backend 就是基于 langgraph studio 构建的
#     - https://github.com/google-gemini/gemini-fullstack-langgraph-quickstart/blob/main/frontend/src/App.tsx#L25-L27
#         - "http://localhost:2024"
#         - "http://localhost:8123",
# - langchain deepagents (research example)
#     - https://github.com/langchain-ai/deepagents/tree/master/examples/research

# %% [markdown]
# - `pip install -U "langgraph-cli[inmem]"`

# %% [markdown]
# ### langgraph.json

# %% [markdown]
# ```json
# {
#     "dependencies": ["."],
#     "graphs": {
#         "react_agent": "./graph.py:app"
#     },
#     "env": ".env"
# }
# ```

# %% [markdown]
# ### cli

# %% [markdown]
# ```
# $ langgraph dev
# ```
#
# - 如果代码没有问题，会自动跳转到 `https://smith.langchain.com/studio/?baseUrl=http://127.0.0.1:2024`
# - 后端代码的修改可直接实时重新启动

# %% [markdown]
# - interrupts
#     - 各个节点的 before/after
#         - model
#         - tools
# - UI：graph/chat
