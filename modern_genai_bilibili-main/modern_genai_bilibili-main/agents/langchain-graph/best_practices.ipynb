# %% [markdown]
# - https://blog.langchain.com/how-to-turn-claude-code-into-a-domain-specific-coding-agent/
# - https://github.com/langchain-ai/claude-code-evals.git

# %% [markdown]
# ### with_structured_output

# %% [markdown]
# - 节点间传递的最好是`结构化/实例化`后的 pydantic model 对象
#     - 某种意义上也是一种 specification driven
# - decision/rating 要给出理由
#     ```
#     justification
#     rationale
#     ```
# - feedback: **Actionable** Feedback;
