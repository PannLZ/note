# %% [markdown]
# - add
#     - 不是添加文件，指代***“将该路径下的最新状态变化（包含新增、修改、甚至是删除），登记（Stage）到暂存区中”**。

# %% [markdown]
# - codespaces：云端开发环境（cloud-based development environment）
#     - 托管在云端的 VS Code + Linux 开发主机
#     - 用浏览器或本地 VS Code 连接
#     - 代码和运行环境都在云服务器上。
