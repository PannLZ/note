# %% [markdown]
# - cpu vs. gpu vs. npu
#     - cpu 太慢，算力不够；
#     - gpu：带宽够大；
#         - 传统的 gpu 着色器（shader cores）为图形渲染设计，算力密度低（能效低）？
#     - npu：能效高；内存太小；

# %% [markdown]
# ### gpu: 图形渲染 & 通用计算

# %% [markdown]
# - shader cores：
#     - 擅长 vector operations
#     - 现在 llm 中，需要的是 Matrix Multiplication
