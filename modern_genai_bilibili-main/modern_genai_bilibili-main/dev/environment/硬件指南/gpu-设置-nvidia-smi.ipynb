# %% [markdown]
# - `sudo nvidia-smi -i 0 -pl 400` (for 5090)
#     - 将 0 号 GPU 的最大功率限制（Power Limit）设置为 400 瓦。

# %% [markdown]
# ### nvidia-smi

# %% [markdown]
# - perf 列
#     - Performance State（P-State）。官方文档里明确写到：它表示 GPU 的当前性能状态，范围通常从 P0 到 P12（有些接口里可到 P15），其中 P0 是最高性能状态，数字越大通常越偏向低功耗。
# - Pwr: Usage/Cap
#     - PCIe 比着 SXM 功耗 cap 会低很多
