# %% [markdown]
# - asyncio 是协程，而非线程
# - multiprocessing：适用于 cpu 密集任务
# - `client.get_tools()` 是一个异步方法（返回一个 `coroutine`），而你在 Python 脚本的顶层直接使用了 `await`，这在普通脚本中是不允许的
#     - 只能在异步函数（`async def fun()`）内使用 await；

# %% [markdown]
# ### 信号量的并发控制

# %% [markdown]
# ```python
# semaphore = asyncio.Semaphore(2)
# ```
