# %% [markdown]
# - 每一个 Python 进程都有属于它自己的一个 Python 解释器实例。每一个 Python 解释器实例都有一把属于它自己的 GIL。
#     - python 的多线程是假的多线程

# %% [markdown]
# - 线程：共享内存，适合 I/O 密集
#     - 线程对 I/O 密集任务有效，争抢唯一的 gil
# - 进程：独立内存，适合 CPU 密集
#     - 线程对 CPU 密集任务无效（需要用多进程）
