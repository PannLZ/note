# %% [markdown]
# - `ssh -f -N -L 9999:ip_b:1245 ip_a`
#     - 本机可以直连 ip_a，不可以连 ip_b，但ip_a 可以连 ip_b
#     - -L：本地端口转发
#         - 本机的 9999 端口通过 ip_a 转发到 ip_b 的1245端口
#     - -N：不执行远程命令，只做转发
#     - -f：认证成功后自己退到后台
