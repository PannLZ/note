# %% [markdown]
# - 两大配置文件
#     - `/etc/hosts`
#     - `/etc/resolv.conf`

# %% [markdown]
# - Google 的公共 DNS 服务器：`8.8.8.8`
# - nslookup: name server loopup
#     - 将域名（如 ssh.github.com）解析为计算机能识别的 IP 地址。
#     - `nslookup ssh.github.com 8.8.8.8`
#         - 使用 Google 的公共 DNS 服务器（8.8.8.8），查询域名 ssh.github.com 对应的真实 IP 地址。
