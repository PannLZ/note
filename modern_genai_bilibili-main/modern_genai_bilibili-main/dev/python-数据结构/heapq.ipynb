# %% [markdown]
# ### queue

# %%
from queue import Queue
from collections import deque

# %% [markdown]
# - Queue:
#     - put
# - deque: 双端队列
#     - 构造：
#         - maxlen
#     - append / popleft
