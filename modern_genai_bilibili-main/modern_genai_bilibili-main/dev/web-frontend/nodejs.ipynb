# %% [markdown]
# - node.js 并不是一个专门的编程语言，而是一个让 JavaScript 可以在服务器端运行的运行时环境；
#     - `node index.js`
# - package.json
#     - 绝大部分 node.js 项目都会在根目录创建一个名为 package.json 的 json 文件，用于记录项目的元数据和各类配置信息（项目名称、版本、程序入口等）
#     - 定义了如何构建、运行和管理 node.js 程序；
#     - 当创建一个新的 node.js 项目时，可以通过执行 `npm init`命令来生成一个基础的 package.json 文件，引导式补充项目的配置信息；
