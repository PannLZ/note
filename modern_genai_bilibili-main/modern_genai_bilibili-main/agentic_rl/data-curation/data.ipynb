# %% [markdown]
# - data recipe：配方/配比
# - sft vs. rl post-training（风格化 response）
#     - sft：prompt & response
#     - rl：prompt & reward model
# - reward hacking
#     - length
# - 混合训练策略 (Mixed Training Strategy)：为了防止 Catastrophic Forgetting（灾难性遗忘）并保持 Gemini 原有的推理能力，SIMA 2 使用了混合数据微调：

# %% [markdown]
# ### 数据从哪里来

# %% [markdown]
# - 已有开源数据
# - 人类标注
# - 合成
#     - sample agent trajectory
# - 参考范文
#     - sima2，人类交互产生具体的动作，gemini pro 根据输入以及人类的输出，脑补思维链（reasoning trace）
