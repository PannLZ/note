# %% [markdown]
# ```
# unset RAY_ADDRESS
# ```
# - 避免其他用户开启的 ray service，verl 内部会启动一个 local ray cluster
#     - 也许需要组合如下的参数使用：
# ```
# +ray_kwargs.ray_init.address=local \
# ```

# %% [markdown]
# ### debug

# %% [markdown]
# - 注意 ray 以及 debugpy 的版本
#     - `pip show ray`
#     - `pip show debugpy`
# - slurm 集群
#     ```
#     ray start --head --ray-debugger-external --port 6379 --dashboard-host 0.0.0.0
#     ```
#     - 或者在配置 ray distributed debuger 时，用具体的计算节点的 ip 而不是 127.0.0.1
