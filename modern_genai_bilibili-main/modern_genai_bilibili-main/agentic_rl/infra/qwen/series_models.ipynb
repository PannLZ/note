# %% [markdown]
# - qwen3: https://huggingface.co/collections/Qwen/qwen3
#     - qwen3
#         - enable_thinking=False
#     - qwen3-2507: 235B-A22B, 30B-A3B, and 4B.
#         - Qwen3-Instruct-2507: Qwen3-Instruct-2507 supports only non-thinking mode and does not generate `<think></think>` blocks in its output. Meanwhile, specifying enable_thinking=False is no longer required.
#             - Qwen3-30B-A3B-Instruct-2507
#         - Qwen3-Thinking-2507: Qwen3-Thinking-2507 supports only thinking mode. Additionally, to enforce model thinking, the default chat template automatically includes `<think>`. Therefore, it is normal for the model's output to contain only `</think>` without an explicit opening `<think>` tag.
#             - Qwen3-4B-Thinking-2507/
