# %% [markdown]
# - gpt-oss 系列：官方给了量化版本
#     - mxfp4
#     - 120b理论上只要60g显存
#         - 120*2 / 4 = 60
# - int4 quantization
#     - Kimi-K2.5 adopts the same native int4 quantization method as Kimi-K2-Thinking.
#         - 官方 Hugging Face 权重目录本身就约 595 GB，这已经说明它虽然是原生 INT4，
#         - 1000 * 2 / 4 = 500 ??
#     - https://github.com/kvcache-ai/ktransformers/blob/main/doc/en/Kimi-K2.5.md
#         -  offloading experts to CPU.
#     -  https://huggingface.co/moonshotai/Kimi-K2.5/blob/main/docs/deploy_guidance.md
#         -  h200 * 8
