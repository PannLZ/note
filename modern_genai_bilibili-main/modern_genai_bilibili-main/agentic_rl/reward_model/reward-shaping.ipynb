# %% [markdown]
# - https://cursor.com/cn/blog/tab-rl
#     - 文中提到了 reward shaping 的一种策略（权衡“建议接受率”与“打扰用户”），接受(accept)： +0.75, 拒绝(reject)：-0.25，不显示(no show)：0。
# - verl reward shaping
#     - https://github.com/volcengine/verl/blob/main/examples/sglang_multiturn/gsm8k_toolcall_shaping/gsm8k_toolcall_shaping.py
