# %% [markdown]
# - task specific instruction
#     - locate
#         - Locate the person who acted bravely in the image...
#     - detect
#         - Detect all red cars in the image...
#     - identity and detect
#         - Identify basketball players and detect key points...
#     - count and detect
#         - Count and detect all birds in this image...
# - output
#     - bbox_2d: `{"bbox_2d": [341, 258, 397, 360]}`
#     - bbox_3d: `["bbox_3d":[x_center, y_center, z_center, x_size, y_size, z_size, roll, pitch, yaw],"label":"category"]`
#     - point_2d: `{"point_2d": ["394", "105"]}`
