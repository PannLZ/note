# %% [markdown]
# - huggingface trl
#     - https://github.com/huggingface/trl/tree/main/examples/notebooks
# - sft
#     - Qwen/Qwen3-VL-4B-Instruct
#         - https://colab.research.google.com/github/huggingface/trl/blob/main/examples/notebooks/sft_qwen_vl.ipynb
#     - unsloth/qwen3-14b-unsloth-bnb-4bit
#         - https://colab.research.google.com/github/huggingface/trl/blob/main/examples/notebooks/sft_trl_lora_qlora.ipynb
# - grpo Qwen/Qwen3-VL-4B-Instruct
#     - https://colab.research.google.com/github/huggingface/trl/blob/main/examples/notebooks/grpo_qwen3_vl.ipynb
# - agent-training (tools)
#     - https://colab.research.google.com/drive/1ZcQeq7irohIMP1bBh_n3H9Ak3Dm5Yu1y?usp=sharing
