# %% [markdown]
# - Agentic rl，learn 一个policy model跟环境动态交互（通过动作/function calling）
# - 纯推理模式下的agent loop就是react，实现了langchain这样的llm框架做的所谓流程编排的事情
# - https://github.com/volcengine/verl/tree/main/examples/tutorial/agent_loop_get_started
