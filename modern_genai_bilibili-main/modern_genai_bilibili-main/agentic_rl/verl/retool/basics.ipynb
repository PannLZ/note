# %% [markdown]
# - python3 -m verl.trainer.main_ppo --config-path=xx/verl/verl/trainer/config --config-name xx.yaml

# %% [markdown]
# ### data preprocess & config

# %% [markdown]
# - `examples/data_preprocess/gsm8k_tool_agent_loop.py`
#     - agent_name: tool_agent
# - config
#     - multi_turn: enable
#     - rollout:
#         - mode: async
# - tools
#     - sandbox_fusion_tool_config
#     - search_tool_config
#     - mcp_tool_config
