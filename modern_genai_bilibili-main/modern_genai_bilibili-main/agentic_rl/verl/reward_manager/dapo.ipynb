# %% [markdown]
# - naive: $R_{\text{naive}}=S$
#     - verl/workers/reward_manager/naive.py
# - DAPO: $R_{\text{dapo}}=S+P_{\text{overlong}}$
#     - verl/workers/reward_manager/dapo.py
#
# $$
# P=\min(-\frac{L_{resp}-(L_{max}-L_{buf})}{L_{buf}}\cdot \alpha, 0)
# $$
