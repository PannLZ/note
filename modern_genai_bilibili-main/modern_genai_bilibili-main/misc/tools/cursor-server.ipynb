# %% [markdown]
# - 必要插件
#     - 右侧提示代码提交记录，git blame

# %% [markdown]
# ### 手动安装

# %% [markdown]
# - 现在直接remote启动安装日志中（output）中找到 commit id
# - 本地下载正确版本
# ```
# COMMIT=b3573281c4775bfc6bba466bf6563d3d498d1070
# curl -L -o vscode-reh-linux-x64.tar.gz \
#   "https://cursor.blob.core.windows.net/remote-releases/${COMMIT}/vscode-reh-linux-x64.tar.gz"
# ```
# - 服务器端手动安装
# ```
# mkdir -p ~/.cursor-server/cli/servers/Stable-b3573281c4775bfc6bba466bf6563d3d498d1070/server
#
# tar -xvzf ~/vscode-reh-linux-x64.tar.gz -C ~/.cursor-server/cli/servers/Stable-b3573281c4775bfc6bba466bf6563d3d498d1070/server --strip-components=1
#
# #
# ls ~/.cursor-server/cli/servers/Stable-b3573281c4775bfc6bba466bf6563d3d498d1070/server
# ```
