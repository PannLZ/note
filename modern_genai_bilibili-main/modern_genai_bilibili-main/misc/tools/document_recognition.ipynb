# %% [markdown]
# - document recognition （ocr)
#     - official：https://huggingface.co/tencent/POINTS-Reader
#     - Deploy and Fine-tuning：https://github.com/ninehills/POINTS-Reader.git

# %% [markdown]
# ### architecture

# %% [markdown]
# - llm
# - vision_encoder
# - vision_projector
