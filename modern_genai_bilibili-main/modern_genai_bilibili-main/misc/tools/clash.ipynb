# %% [markdown]
# - config: global/rule/direct
# - rules: 配置哪些网站走节点选择，那些走直连；
# - proxies
#     - 节点选择
#     - 全球直连
#     - 漏网之鱼
#     - global
#         - 只有在你将软件的系统模式（System Mode） 设置为 全局模式 (Global Mode) 时才会生效。在默认的 规则模式 (Rule Mode) 下，这个组是不起作用的。

# %% [markdown]
# ### system proxy

# %% [markdown]
# - `scutil --proxy`：查看是否全局生效
#     - macOS 操作系统中用于查询当前系统网络代理（Proxy）配置状态的底层命令行工具。

# %% [markdown]
# ### clash for linux

# %% [markdown]
# - https://github.com/wnlen/clash-for-linux：用 cursor 管理和排查问题
#     - .env: 配置订阅地址
#     - `sudo bash start.sh`
#         - 会输出 secret 信息；
#     - `source /etc/profile.d/clash.sh`
#     - `proxy_on`
#         - `proxy_off`
# - Dashboard ui 设置节点
#     - `http://<ip>:9090/ui`
#         - 填写 secret，add 之后进入管理页面；
#         - label 随便写不必要；
# - `curl https://ipinfo.io`
#     - 查看 ip；
#     - `curl -L ping0.cc/geo`: 查看 ip 归属
