# %% [markdown]
# - Hands-On-Large-Language-Models (Jay Alammar)
#     - https://github.com/HandsOnLLM/Hands-On-Large-Language-Models.git
# - llm from scratch (Sebastian Raschka)
#     - https://github.com/rasbt/LLMs-from-scratch.git
# - reasoning model from scratch (Sebastian Raschka)
#     - https://github.com/rasbt/reasoning-from-scratch.git
# - nanoGPT (Andrej Karpathy)
#     - https://github.com/karpathy/nanoGPT.git

# %% [markdown]
# - datasets
#     - https://github.com/mlabonne/llm-datasets.git

# %% [markdown]
# - infra
#     - https://github.com/zhaochenyang20/Awesome-ML-SYS-Tutorial.git

# %% [markdown]
# - langchain/langgraph
#     - https://github.com/langchain-ai/rag-from-scratch.git
