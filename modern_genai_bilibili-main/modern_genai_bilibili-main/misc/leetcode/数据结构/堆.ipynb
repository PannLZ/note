# %% [markdown]
# - 堆，是完全二叉树，非常适合用数组来存储
#     - 0 号为根，然后按层编码存储；
# - 基于下标索引
#     - left child: $2i+1$
#     - right child: $2i+2$
#     - parent: $(i-1)/2$
# - 建堆的时间复杂度分析

# %% [markdown]
# ### 堆的插入

# %% [markdown]
# ### 堆顶删除
