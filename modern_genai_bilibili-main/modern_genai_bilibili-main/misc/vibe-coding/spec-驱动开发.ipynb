# %% [markdown]
# > SDD：Spec-Driven Development
#
# - https://mp.weixin.qq.com/s/jQRB9B9Nt0-_5QPgq4_6TA
#     - PRD 需求文档（Product Requirements Document）
#     - `新需求首次沟通时，末尾强调 「不要急着写代码！先理解需求，给出实现思路，我们先讨论，看还有啥需要我决策的点？ultrathink 」`

# %% [markdown]
# - 或者就是一个简单的 cursor rule
#     - `不明白的地方反问我，先不着急编码`
