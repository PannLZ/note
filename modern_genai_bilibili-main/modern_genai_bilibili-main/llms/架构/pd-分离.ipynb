# %% [markdown]
# - Prefill 集中到高算力卡上批量跑，Decode 散到其他卡上慢慢蹦，中间把 KV cache 传过去就行。
#     - Linear 的 hybrid attention 压缩了 KV cache，这使得传输不再变得那么不可行。而即便是可能可行，也需要足够多的线上流量才能证明真的可行。(prefill-as-a-service)
#     - 中间传过去这一步要的网络才是最致命的。要不然deepseek也不会发论文写全双工网络回传来解决KV填充和推理这个异步过程中网络带宽资源的浪费问题了。(dualpath)
