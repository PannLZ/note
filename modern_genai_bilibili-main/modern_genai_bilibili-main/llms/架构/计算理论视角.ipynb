# %% [markdown]
# - https://www.zhihu.com/question/1992208967498236682/answer/2028074933238907033

# %% [markdown]
# ### 为什么大模型做不好数数

# %% [markdown]
# - 计数：皮亚诺公理

# %% [markdown]
# ### bash 即一切？？

# %% [markdown]
# - 在形式语言理论中，$Dyck-k$ 语言指的是由 $k$ 种不同的括号（或引号）组成的、完全正确闭合的字符串集合。例如，{ [ ( ) ] } 属于 $Dyck-3$（包含大、中、小括号三种），而 Bash 命令中交织的单引号、双引号、反引号以及 $() 括号，实质上构成了极为复杂的 $Dyck-k$ 匹配任务。
