# %%
from IPython.display import Image

# %% [markdown]
# - https://fi-le.net/oss/
#     - https://cookbook.openai.com/articles/gpt-oss/run-transformers
# - token embedding 的范数
#     - “中文垃圾词”会高范数
# - tool urls
#     - https://tiktokenizer.vercel.app/
#     - https://github.com/openai/tiktoken/blob/main/tiktoken/model.py

# %% [markdown]
# ### embedding hist

# %% [markdown]
# - `pip install -U transformers accelerate torch triton==3.4 kernels torchvision`
#     - https://cookbook.openai.com/articles/gpt-oss/run-transformers

# %% [markdown]
# - https://chatgpt.com/c/68e74996-44e0-8324-8da9-0164208ffde0
#
# ```python
# import matplotlib.pyplot as plt
# import torch
# import os
#
# model_dir = "~/gpt-oss-20b"
#
# tokenizer = AutoTokenizer.from_pretrained(model_name)
#
# # 不设置 device_map，默认全在 CPU；只为拿 embedding，不做推理
# model = AutoModelForCausalLM.from_pretrained(
#     model_dir,
#     torch_dtype="auto",
#     #device_map="auto"
# )
#
# emb = model.get_input_embeddings()
# print(emb.weight.shape)
# weight = emb.weight.detach().to(torch.float32).cpu().numpy()
# norms = np.linalg.norm(weight, axis=1).astype(np.float32)
# plt.figure(figsize=(8, 5))
# plt.hist(norms, bins=200)
# plt.yscale("log")  # 分布通常长尾，log y 更清晰
# plt.xlabel("L2 norm of embedding rows")
# plt.ylabel("Count (log scale)")
# plt.title(f"Embedding L2-Norm Histogram for gpt-oss-20b")
# plt.tight_layout()
# plt.savefig('oss_emb_hist.png', dpi=180)
# ```
#
# - emb.weight.shape
#     - `[201088, 2880]`

# %%
Image(url='./figs/oss_emb_hist.png', width=500)
# Out:
# <img src="./figs/oss_emb_hist.png" width="500"/>
