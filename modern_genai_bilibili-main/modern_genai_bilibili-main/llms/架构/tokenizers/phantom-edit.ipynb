# %% [markdown]
# - Say Anything but This: When Tokenizer Betrays Reasoning in LLMs
#     - 它表示 token ID 变了，但 detokenize 后的表面词没变。比如 Conservative 或 register 在最终文本里仍然显示为同一个词，但底层 token ID 序列已经换成了另一种编码。模型可能“以为”自己完成了替换，因为输出 token ID 与输入不同；但从文本层面看，词没有被替换。这就是 phantom edit。论文明确指出，Figure 1 的红色区域展示的正是“不同 token-ID 表征解码成相同表面词”的情况，根源是 tokenization 的非唯一性。
#     - 把 LLM 的“推理失败”拆成了两个层面：token 空间的操作成功，surface text 空间的语义失败。
