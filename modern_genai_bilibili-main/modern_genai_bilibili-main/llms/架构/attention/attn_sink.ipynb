# %% [markdown]
# ### why bos token

# %% [markdown]
# BOS 的“位置特权”：全员可见（Universal Visibility）。在 Causal Masking（因果掩码，即只能看左边）的机制下：
# - 第 100 个 token 能看到第 1 到 99 个。
# - 第 5 个 token 只能看到第 1 到 4 个。
# - 只有第 1 个 Token（BOS），是所有后续 Token（无论处于第几层、第几步）都绝对能看到的。
