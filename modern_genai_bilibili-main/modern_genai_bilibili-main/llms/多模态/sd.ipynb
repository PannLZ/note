# %% [markdown]
# - 预训练 vae （from stable diffusion）
# - apps
#     - text2img
#     - img2img（impaint）

# %% [markdown]
# ### pipeline

# %% [markdown]
# - VAE：像素域 ↔ 潜空间（latent）的编解码器。把图片压到小而“语义密集”的 latent，再把最终 latent 还原成像素图。
# - UNet：在latent 空间里做去噪/反扩散的核心网络，根据文本条件把随机噪声一步步变成“干净的”latent。

# %% [markdown]
# ### cross attention
