# %% [markdown]
# - grounded sam2
#     - 它不是一个全新的单一模型，而是一个工作流（Pipeline）。它把 Grounding DINO（一个强大的零样本目标检测模型）和 SAM 2 串联了起来。

# %% [markdown]
# ### 跨帧物体 id 一致性

# %% [markdown]
# - SAM2/3 Video Predictor 的 Mask Propagation（掩码传播） 功能来实现跨帧物体追踪。
#     - 本质上是 object tracking 能力；
#     - Re-ID：SAM 2 具备处理物体“消失再出现”（Occlusion/Re-appearance）的能力，并且能够保持同一个 ID，但这取决于消失的时间长短以及具体的场景复杂性。
#     - sam2 -> sam2long (training free)
#     - sam3 会比 sam2 tracking 能力更强一些；
