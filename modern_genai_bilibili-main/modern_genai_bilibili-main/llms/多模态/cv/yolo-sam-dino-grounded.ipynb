# %%
from IPython.display import Image

# %% [markdown]
# - sam，dino，grouned dino
#     - grounding dino: open-set object detection，开集目标检测
# - grouded sam

# %% [markdown]
# ### grouding sam2

# %%
Image(url='./imgs/g_sam2_tracking_pipeline_vis_new.png', width=800)
# Out:
# <img src="./imgs/g_sam2_tracking_pipeline_vis_new.png" width="800"/>

# %% [markdown]
# - https://github.com/IDEA-Research/Grounded-SAM-2
#     - https://github.com/IDEA-Research/Grounded-SAM-2/blob/main/grounded_sam2_tracking_demo.py

# %% [markdown]
# ### sam variant

# %% [markdown]
# - LangSAM: 你只要给它一个名字（"screwdriver"），它就能把图里所有的螺丝刀都涂上颜色（生成掩码 Mask）。
