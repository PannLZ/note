# %% [markdown]
# - human-like “personalities” and “moods,”
# - character traits – like evil, sycophancy (insincere flattery), or propensity to hallucinate (make up false information).
#     - 邪恶、谄媚（不真诚的奉承）或产生幻觉（编造虚假信息）
