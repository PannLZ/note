# %% [markdown]
# - https://www.youtube.com/watch?v=F2jd5WuT-zg

# %%
from IPython.display import Image

# %% [markdown]
# ### logit lens

# %% [markdown]
# > 把每一层（更准确地说，每个层后的“残差流” residual stream）的表示（contextied representation），直接用模型自己的 读出头（unembedding / readout matrix）投到词表上，看“此时此刻模型已经在想哪些词”（整个词表上 logits 的数值来刻画）。

# %%
Image(url='./figs/unembed.png', width=400)
# Out:
# <img src="./figs/unembed.png" width="400"/>

# %% [markdown]
# - 从 ubembed（lm head）说起：
#     - 如果 tie word embed，其实就是 embedding table vocabulary中的每个token embedding跟 input seq中的最后一个 token embedding，逐个 dot product（计算内积也就是相似度）的过程

# %% [markdown]
# ### Steering

# %% [markdown]
# > representation engineering, activation engineering, activation steering ...
#
# - core directions
#     - 接受/拒绝回答；
