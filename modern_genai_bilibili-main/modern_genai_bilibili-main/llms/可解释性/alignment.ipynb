# %% [markdown]
# - Anthropic：values in the wild
#     - https://www.anthropic.com/research/values-wild
#         - https://www.xiaoqiedun.com/posts/2025-04-22-values-wild/
#         - 有用的、诚实的和无害的 (3H：helpful, honest, and harmless)。
